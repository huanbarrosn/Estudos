# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np

dataset = pd.read_csv("C:/Users/audax/Documents/Projetos/estudos/programacao/sql_com_mysql/data/telecom/telecom_customer_churn.csv")



valores_corr = [dataset['Customer Status'].corr(other=dataset[campo], method="spearman") for campo in dataset.columns[:-3]]
df_corr = pd.DataFrame(valores_corr, columns=['Customer Status'])

df_corr['Outras colunas'] = dataset.columns[:-3]

df_corr
# Out:
#     Customer Status                     Outras colunas
# 0          0.019179                        Customer ID
# 1          0.002437                             Gender
# 2         -0.087526                                Age
# 3          0.207828                            Married
# 4          0.255581               Number of Dependents
# 5         -0.024063                               City
# 6          0.024532                           Zip Code
# 7          0.045965                           Latitude
# 8         -0.030430                          Longitude
# 9          0.279284                Number of Referrals
# 10         0.508684                   Tenure in Months
# 11        -0.078629                              Offer
# 12        -0.016205                      Phone Service
# 13         0.004792  Avg Monthly Long Distance Charges
# 14         0.032533                     Multiple Lines
# 15        -0.180486                   Internet Service
# ...
